# %% [markdown]
# ### Import

# %%
import time
import os
import cfbd
from cfbd.models.betting_game import BettingGame
from cfbd.models.season_type import SeasonType
from cfbd.models.advanced_box_score import AdvancedBoxScore
from cfbd.rest import ApiException
from pprint import pprint
import pandas as pd
from datetime import datetime
import math
from cfbd.models.division_classification import DivisionClassification
from cfbd.models.scoreboard_game import ScoreboardGame
from cfbd.models.live_game import LiveGame

# %% [markdown]
# ### Betlines COMPLETE
#
# Order -> API Call function def -> Duration def -> Finally call duration def function

# %%
### Get_baselines ####
def get_betlines(year=2025, season_type="regular", home='georgia tech', away='clemson'):   
    # Defining the host is optional and defaults to https://api.collegefootballdata.com
    # See configuration.py for a list of all supported configuration parameters.
    configuration = cfbd.Configuration(
        host = "https://api.collegefootballdata.com"
    )

    # The client must configure the authentication and authorization parameters
    # in accordance with the API server security policy.
    # Examples for each auth method are provided below, use the example that
    # satisfies your auth use case.

    # Configure Bearer authorization: apiKey
    configuration = cfbd.Configuration(
        access_token = os.environ["BEARER_TOKEN"]
    )

    # Enter a context with an instance of the API client
    with cfbd.ApiClient(configuration) as api_client:
        # Create an instance of the API class
        api_instance = cfbd.BettingApi(api_client)
        
        ##boilerplate 
        # game_id = 56 # int | Optional gameId filter (optional)
        # year = 2025 # int | Year filter, required if game id not specified (optional)
        # season_type = "regular" # SeasonType | Optional season type filter (optional)
        # home = 'georgia tech' # str | Optional home team filter (optional)
        # away = 'clemson' # str | Optional away team filter (optional)
        # conference = 'conference_example' # str | Optional conference filter (optional)
        # provider = 'provider_example' # str | Optional provider name filter (optional)

        try:
            api_response = api_instance.get_lines(year=year, season_type=season_type, home=home, away=away) # this is the json file with all the gotten data in int. 
            print("The response of BettingApi->get_lines:\n")
            pprint(api_response)
        except Exception as e:
            print("Exception when calling BettingApi->get_lines: %s\n" % e)

        return api_response

# %%
def run_betlines_for_duration(duration_hours=3.5, sleep_time = 15, big_filename="betlines_full.csv", year=2025, season_type="regular", home='georgia tech', away='clemson'):
    start_time = time.time()
    all_dfs = []
    iterations = math.ceil((duration_hours * 60) / sleep_time)
    
    for _ in range(iterations):
        print(f"Iteration #{_}")
        api_response = get_betlines(year, season_type, home, away)
        df = pd.DataFrame([bet.to_dict() for bet in api_response])
        df['time_stamp'] = current_datetime = datetime.now()
        all_dfs.append(df)
        
        # Save each iteration as before (optional)
        # timestamp = datetime.now().strftime("%Y%m%d_%H%M")
        # filename = f"betlines_{timestamp}.csv"
        # df.to_csv(filename, index=False)
        # print(f"Saved {filename}")
        
        # Wait for 15 minutes unless time is up
        if (time.time() - start_time) >= duration_hours * 3600: 
            break
        time.sleep(sleep_time * 60)
    
    # Concatenate all DataFrames and save to a big CSV
    big_df = pd.concat(all_dfs, ignore_index=True)
    # big_filename = "betlines_full.csv"
    big_df.to_csv(big_filename, index=False)
    print(f"Saved all data to {big_filename}")

# %%
# run_betlines_for_duration(duration_hours=(1/30), sleep_time = 1)

# %% [markdown]
# ### Scoreboard

# %%
### Get_baselines ####
def get_score():   
    # Defining the host is optional and defaults to https://api.collegefootballdata.com
    # See configuration.py for a list of all supported configuration parameters.
    configuration = cfbd.Configuration(
        host = "https://api.collegefootballdata.com"
    )

    # The client must configure the authentication and authorization parameters
    # in accordance with the API server security policy.
    # Examples for each auth method are provided below, use the example that
    # satisfies your auth use case.

    # Configure Bearer authorization: apiKey
    configuration = cfbd.Configuration(
        access_token = os.environ["BEARER_TOKEN"]
    )

    # Enter a context with an instance of the API client
    with cfbd.ApiClient(configuration) as api_client:
        # Create an instance of the API class
        api_instance = cfbd.GamesApi(api_client)
        classification = "fbs" # DivisionClassification | Optional division classification filter, defaults to fbs (optional)
        try:
            api_response = api_instance.get_scoreboard(classification=classification)
            print("The response of GamesApi->get_scoreboard:\n")
            #pprint(api_response)
        except Exception as e:
            print("Exception when calling GamesApi->get_scoreboard: %s\n" % e)
        return api_response

# %%
def run_score_for_duration(duration_hours=3.5, sleep_time = 15, big_filename="scores.csv", year=2025, season_type="regular", home='georgia tech', away='clemson'):
    start_time = time.time()
    all_dfs = []
    iterations = math.ceil((duration_hours * 60) / sleep_time)
    
    for _ in range(iterations):
        print(f"Iteration #{_}")
        api_response = get_score()
        df = pd.DataFrame([bet.to_dict() for bet in api_response])
        df['time_stamp'] = current_datetime = datetime.now()
        all_dfs.append(df)
        
        
        # Wait for 15 minutes unless time is up
        if (time.time() - start_time) >= duration_hours * 3600: 
            break
        time.sleep(sleep_time * 60)
    
    # Concatenate all DataFrames and save to a big CSV
    big_df = pd.concat(all_dfs, ignore_index=True)
    # big_filename = "betlines_full.csv"
    big_df.to_csv(big_filename, index=False)
    print(f"Saved all data to {big_filename}")

# %%
run_score_for_duration(duration_hours=(1/240), sleep_time = .05)
# Out:
# Iteration #0
# The response of GamesApi->get_scoreboard:
#
# Iteration #1
# The response of GamesApi->get_scoreboard:
#
# Iteration #2
# The response of GamesApi->get_scoreboard:
#
# Saved all data to scores.csv

# %% [markdown]
# ### BOX SCORE

# %%
def get_live_game(game_id=56):   
    # Defining the host is optional and defaults to https://api.collegefootballdata.com
    # See configuration.py for a list of all supported configuration parameters.
    configuration = cfbd.Configuration(
        host = "https://api.collegefootballdata.com"
    )

    # The client must configure the authentication and authorization parameters
    # in accordance with the API server security policy.
    # Examples for each auth method are provided below, use the example that
    # satisfies your auth use case.

    # Configure Bearer authorization: apiKey
    configuration = cfbd.Configuration(
        access_token = os.environ["BEARER_TOKEN"]
    )

    # Enter a context with an instance of the API client
    with cfbd.ApiClient(configuration) as api_client:
        # Create an instance of the API class
        api_instance = cfbd.PlaysApi(api_client)

        try:
            api_response = api_instance.get_live_plays(game_id=game_id)
            print("The response of PlaysApi->get_live_plays:\n")
            pprint(api_response)
            return api_response
        except Exception as e:
            print("Exception when calling PlaysApi->get_live_plays: %s\n" % e)

# %%
import json

# Correct list of game IDs
ids = [401754537, 401756905, 401754547, 401754545, 401752717, 401752725, 401752719, 401752851, ] 

# 401754543, 401752850



# 1. Create an empty list BEFORE the loop to store all game data
all_games_data = []

# 2. Loop through each game ID
for game_id in ids:  
    print(game_id)
    # This call returns a SINGLE LiveGame object
    live_game_object = get_live_game(game_id=int(game_id))
    
    # If the game data doesn't exist, skip to the next ID
    if not live_game_object: 
        continue

    # 3. Convert the single object to a dictionary and append it to our list.
    #    DO NOT loop over the live_game_object itself.
    game_dict = live_game_object.to_dict()
    all_games_data.append(game_dict)


# 4. AFTER the loop is finished, write the complete list to the file once.
with open("live_scores.json", 'w') as json_file:
    # 1. Define a converter function to handle datetime objects
    def datetime_converter(o):
        # Check if the object is an instance of the datetime class
        if isinstance(o, datetime):
            # If so, convert it to an ISO 8601 formatted string
            return o.isoformat()

# 2. Call json.dump() and pass your new function to the 'default' parameter
with open("live_scores.json", 'w') as json_file:
    json.dump(all_games_data, json_file, indent=4, default=datetime_converter)
# Out:
# 401754537
# The response of PlaysApi->get_live_plays:
#
# LiveGame(id=401754537, status='Final', period=None, clock='', possession='', down=None, distance=None, yards_to_goal=None, teams=[LiveGameTeam(team_id=228, team='Clemson', home_away='home', line_scores=[7, 7, 0, 7], points=21, drives=13, scoring_opportunities=7, points_per_opportunity=3, average_start_yard_line=79.2, plays=104, line_yards=81, line_yards_per_rush=3.7, second_level_yards=40, second_level_yards_per_rush=1.8, open_field_yards=37, open_field_yards_per_rush=1.7, epa_per_play=0.325, total_epa=26, passing_epa=13, epa_per_pass=0.214, rushing_epa=12.9, epa_per_rush=0.588, success_rate=0.433, standard_down_success_rate=0.507, passing_down_success_rate=0.258, explosiveness=0.803, deserve_to_win=0.793), LiveGameTeam(team_id=183, team='Syracuse', home_away='away', line_scores=[10, 14, 10, 0], points=34, drives=14, scoring_opportunities=8, points_per_opportunity=3.4, average_start_yard_line=65.8, plays=108, line_yards=116.70000000000002, line_yards_per_rush=3.3, second_level_yards=38, second_level_yards_per_rush=1.1, open_field_yards=38, open_field_yards_per_rush=1.1, epa_per_play=0.037, total_epa=2.6, passing_epa=5.7, epa_per_pass=0.143, rushing_epa=-3.1, epa_per_rush=-0.088, success_rate=0.306, standard_down_success_rate=0.262, passing_down_success_rate=0.362, explosiveness=0.976, deserve_to_win=0.20699999999999996)], drives=[LiveGameDrive(id='4017545371', offense_id=183, offense='Syracuse', defense_id=228, defense='Clemson', play_count=7, yards=75, start_period=1, start_clock='15:00', start_yards_to_goal=75, end_period=1, end_clock='11:01', end_yards_to_goal=0, duration='3:59', scoring_opportunity=True, result='Touchdown', points_gained=7, plays=[LiveGamePlay(id='401754537101849903', home_score=0, away_score=0, period=1, clock='15:00', wall_clock=datetime.datetime(2025, 9, 20, 16, 8, 47, tzinfo=datetime.timezone.utc), team_id=228, team='Clemson', down=1, distance=10, yards_to_goal=65, yards_gained=0, play_type_id=53, play_type='Kickoff', epa=None, garbage_time=False, success=False, rush_pass='other', down_type='standard', play_text='Robert Gunn III kickoff for 65 yds for a touchback'), LiveGamePlay(id='401754537101855501', home_score=0, away_score=0, period=1, clock='14:44', wall_clock=datetime.datetime(2025, 9, 20, 16, 9, 7, tzinfo=datetime.timezone.utc), team_id=183, team='Syracuse', down=1, distance=10, yards_to_goal=75, yards_gained=4, play_type_id=5, play_type='Rush', epa=-0.114, garbage_time=False, success=False, rush_pass='rush', down_type='standard', play_text='Yasin Willis run for 4 yds to the SYR 29'), LiveGamePlay(id='401754537101858001', home_score=0, away_score=0, period=1, clock='14:19', wall_clock=datetime.datetime(2025, 9, 20, 16, 9, 34, tzinfo=datetime.timezone.utc), team_id=183, team='Syracuse', down=2, distance=6, yards_to_goal=71, yards_gained=32, play_type_id=5, play_type='Rush', epa=3.052, garbage_time=False, success=True, rush_pass='rush', down_type='standard', play_text='Yasin Willis run for 32 yds to the CLEM 39 for a 1ST down'), LiveGamePlay(id='401754537101867001', home_score=0, away_score=0, period=1, clock='13:29', wall_clock=datetime.datetime(2025, 9, 20, 16, 10, 24, tzinfo=datetime.timezone.utc), team_id=183, team='Syracuse', down=1, distance=10, yards_to_goal=39, yards_gained=5, play_type_id=5, play_type='Rush', epa=0.086, garbage_time=False, success=True, rush_pass='rush', down_type='standard', play_text='Will Nixon run for 5 yds to the CLEM 34'), LiveGamePlay(id='401754537101869001', home_score=0, away_score=0, period=1, clock='13:09', wall_clock=datetime.datetime(2025, 9, 20, 16, 10, 54, tzinfo=datetime.timezone.utc), team_id=183, team='Syracuse', down=2, distance=5, yards_to_goal=34, yards_gained=8, play_type_id=5, play_type='Rush', epa=0.334, garbage_time=False, success=True, rush_pass='rush', down_type='standard', play_text='Steve Angeli run for 8 yds to the CLEM 26 for a 1ST down'), LiveGamePlay(id='401754537101869801', home_score=0, away_score=0, period=1, clock='13:01', wall_clock= ...
# 401756905
# The response of PlaysApi->get_live_plays:
#
# LiveGame(id=401756905, status='Final', period=None, clock='', possession='', down=None, distance=None, yards_to_goal=None, teams=[LiveGameTeam(team_id=2305, team='Kansas', home_away='home', line_scores=[7, 6, 14, 7], points=34, drives=10, scoring_opportunities=7, points_per_opportunity=3.9, average_start_yard_line=78.7, plays=79, line_yards=116.9, line_yards_per_rush=4.3, second_level_yards=47, second_level_yards_per_rush=1.7, open_field_yards=63, open_field_yards_per_rush=2.3, epa_per_play=0.274, total_epa=14, passing_epa=9.9, epa_per_pass=0.355, rushing_epa=4, epa_per_rush=0.149, success_rate=0.468, standard_down_success_rate=0.439, passing_down_success_rate=0.545, explosiveness=0.7, deserve_to_win=0.323), LiveGameTeam(team_id=2132, team='Cincinnati', home_away='away', line_scores=[7, 13, 10, 7], points=37, drives=10, scoring_opportunities=7, points_per_opportunity=5.3, average_start_yard_line=79.7, plays=111, line_yards=148, line_yards_per_rush=4.1, second_level_yards=47, second_level_yards_per_rush=1.3, open_field_yards=55, open_field_yards_per_rush=1.5, epa_per_play=0.375, total_epa=28.8, passing_epa=18.9, epa_per_pass=0.42, rushing_epa=9.9, epa_per_rush=0.276, success_rate=0.423, standard_down_success_rate=0.453, passing_down_success_rate=0.361, explosiveness=0.958, deserve_to_win=0.677)], drives=[LiveGameDrive(id='4017569051', offense_id=2132, offense='Cincinnati', defense_id=2305, defense='Kansas', play_count=6, yards=15, start_period=1, start_clock='15:00', start_yards_to_goal=75, end_period=1, end_clock='11:53', end_yards_to_goal=60, duration='3:07', scoring_opportunity=False, result='Punt', points_gained=0, plays=[LiveGamePlay(id='401756905101849903', home_score=0, away_score=0, period=1, clock='15:00', wall_clock=datetime.datetime(2025, 9, 27, 16, 2, 42, tzinfo=datetime.timezone.utc), team_id=2305, team='Kansas', down=1, distance=10, yards_to_goal=65, yards_gained=0, play_type_id=53, play_type='Kickoff', epa=None, garbage_time=False, success=False, rush_pass='other', down_type='standard', play_text='Laith Marjan kickoff for 65 yds for a touchback'), LiveGamePlay(id='401756905101849905', home_score=0, away_score=0, period=1, clock='15:00', wall_clock=datetime.datetime(2025, 9, 27, 16, 3, 25, tzinfo=datetime.timezone.utc), team_id=2132, team='Cincinnati', down=1, distance=10, yards_to_goal=75, yards_gained=5, play_type_id=5, play_type='Rush', epa=0.095, garbage_time=False, success=True, rush_pass='rush', down_type='standard', play_text='Tawee Walker run for 5 yds to the CIN 30'), LiveGamePlay(id='401756905101849906', home_score=0, away_score=0, period=1, clock='15:00', wall_clock=datetime.datetime(2025, 9, 27, 16, 3, 25, tzinfo=datetime.timezone.utc), team_id=2132, team='Cincinnati', down=2, distance=5, yards_to_goal=70, yards_gained=3, play_type_id=24, play_type='Pass Reception', epa=-0.314, garbage_time=False, success=False, rush_pass='pass', down_type='standard', play_text='Brendan Sorsby pass complete to Cyrus Allen for 3 yds to the CIN 33'), LiveGamePlay(id='401756905101849907', home_score=0, away_score=0, period=1, clock='15:00', wall_clock=datetime.datetime(2025, 9, 27, 16, 3, 25, tzinfo=datetime.timezone.utc), team_id=2132, team='Cincinnati', down=3, distance=2, yards_to_goal=67, yards_gained=10, play_type_id=5, play_type='Rush', epa=1.832, garbage_time=False, success=True, rush_pass='rush', down_type='standard', play_text='Brendan Sorsby run for 10 yds to the CIN 43 for a 1ST down'), LiveGamePlay(id='401756905101849908', home_score=0, away_score=0, period=1, clock='15:00', wall_clock=datetime.datetime(2025, 9, 27, 16, 3, 25, tzinfo=datetime.timezone.utc), team_id=2132, team='Cincinnati', down=1, distance=10, yards_to_goal=57, yards_gained=0, play_type_id=5, play_type='Rush', epa=-1.157, garbage_time=False, success=False, rush_pass='rush', down_type='standard', play_text='Tawee Walker run for no gain to the CIN 43'), LiveGamePlay(id='401756905101849909', home_score=0, away_score=0, period=1, clock='15:00', wa ...
# 401754547
# The response of PlaysApi->get_live_plays:
#
# LiveGame(id=401754547, status='Final', period=None, clock='', possession='', down=None, distance=None, yards_to_goal=None, teams=[LiveGameTeam(team_id=221, team='Pittsburgh', home_away='home', line_scores=[17, 10, 0, 0], points=27, drives=13, scoring_opportunities=9, points_per_opportunity=0.7, average_start_yard_line=72.8, plays=83, line_yards=81.30000000000001, line_yards_per_rush=3.9, second_level_yards=21, second_level_yards_per_rush=1, open_field_yards=10, open_field_yards_per_rush=0.5, epa_per_play=0.494, total_epa=27.6, passing_epa=20.9, epa_per_pass=0.566, rushing_epa=6.7, epa_per_rush=0.319, success_rate=0.325, standard_down_success_rate=0.412, passing_down_success_rate=0.188, explosiveness=0.701, deserve_to_win=0.644), LiveGameTeam(team_id=97, team='Louisville', home_away='away', line_scores=[0, 17, 3, 14], points=34, drives=16, scoring_opportunities=11, points_per_opportunity=1.2, average_start_yard_line=60.4, plays=115, line_yards=82.19999999999999, line_yards_per_rush=2.7, second_level_yards=18, second_level_yards_per_rush=0.6, open_field_yards=5, open_field_yards_per_rush=0.2, epa_per_play=0.034, total_epa=2.7, passing_epa=9, epa_per_pass=0.169, rushing_epa=-6.8, epa_per_rush=-0.22, success_rate=0.348, standard_down_success_rate=0.328, passing_down_success_rate=0.375, explosiveness=0.869, deserve_to_win=0.356)], drives=[LiveGameDrive(id='4017545471', offense_id=221, offense='Pittsburgh', defense_id=97, defense='Louisville', play_count=10, yards=77, start_period=1, start_clock='14:55', start_yards_to_goal=89, end_period=1, end_clock='11:34', end_yards_to_goal=12, duration='3:21', scoring_opportunity=True, result='Field Goal', points_gained=3, plays=[LiveGamePlay(id='401754547101854401', home_score=0, away_score=0, period=1, clock='14:55', wall_clock=datetime.datetime(2025, 9, 27, 16, 3, 46, tzinfo=datetime.timezone.utc), team_id=97, team='Louisville', down=1, distance=10, yards_to_goal=65, yards_gained=8, play_type_id=12, play_type='Kickoff Return (Offense)', epa=None, garbage_time=False, success=True, rush_pass='other', down_type='standard', play_text='Nick Keller kickoff for 62 yds , Cataurus Hicks return for 8 yds to the PITT 11'), LiveGamePlay(id='401754547101855001', home_score=0, away_score=0, period=1, clock='14:49', wall_clock=datetime.datetime(2025, 9, 27, 16, 4, 31, tzinfo=datetime.timezone.utc), team_id=221, team='Pittsburgh', down=1, distance=10, yards_to_goal=89, yards_gained=7, play_type_id=5, play_type='Rush', epa=0.394, garbage_time=False, success=True, rush_pass='rush', down_type='standard', play_text='Juelz Goff run for 7 yds to the PITT 18'), LiveGamePlay(id='401754547101857801', home_score=0, away_score=0, period=1, clock='14:21', wall_clock=datetime.datetime(2025, 9, 27, 16, 3, 46, tzinfo=datetime.timezone.utc), team_id=221, team='Pittsburgh', down=2, distance=3, yards_to_goal=82, yards_gained=12, play_type_id=5, play_type='Rush', epa=0.677, garbage_time=False, success=True, rush_pass='rush', down_type='standard', play_text='Eli Holstein run for 12 yds to the PITT 30 for a 1ST down'), LiveGamePlay(id='401754547101864901', home_score=0, away_score=0, period=1, clock='13:50', wall_clock=datetime.datetime(2025, 9, 27, 16, 3, 46, tzinfo=datetime.timezone.utc), team_id=221, team='Pittsburgh', down=1, distance=10, yards_to_goal=70, yards_gained=7, play_type_id=24, play_type='Pass Reception', epa=0.672, garbage_time=False, success=True, rush_pass='pass', down_type='standard', play_text='Eli Holstein pass complete to Juelz Goff for 7 yds to the PITT 37'), LiveGamePlay(id='401754547101867001', home_score=0, away_score=0, period=1, clock='13:29', wall_clock=datetime.datetime(2025, 9, 27, 16, 3, 46, tzinfo=datetime.timezone.utc), team_id=221, team='Pittsburgh', down=2, distance=3, yards_to_goal=63, yards_gained=6, play_type_id=24, play_type='Pass Reception', epa=0.556, garbage_time=False, success=True, rush_pass='pass', down_type='standard', play_text='Eli Holstein pass complete to Justin Holmes for 6 yd ...
# 401754545
# The response of PlaysApi->get_live_plays:
#
# LiveGame(id=401754545, status='Final', period=None, clock='', possession='', down=None, distance=None, yards_to_goal=None, teams=[LiveGameTeam(team_id=183, team='Syracuse', home_away='home', line_scores=[3, 0, 0, 0], points=3, drives=11, scoring_opportunities=4, points_per_opportunity=0.8, average_start_yard_line=80.4, plays=83, line_yards=102, line_yards_per_rush=3.6, second_level_yards=26, second_level_yards_per_rush=0.9, open_field_yards=37, open_field_yards_per_rush=1.3, epa_per_play=0.118, total_epa=7.6, passing_epa=3.6, epa_per_pass=0.1, rushing_epa=4, epa_per_rush=0.142, success_rate=0.337, standard_down_success_rate=0.415, passing_down_success_rate=0.2, explosiveness=0.964, deserve_to_win=0.041), LiveGameTeam(team_id=150, team='Duke', home_away='away', line_scores=[10, 14, 7, 7], points=38, drives=12, scoring_opportunities=7, points_per_opportunity=5.4, average_start_yard_line=69.1, plays=89, line_yards=138.5, line_yards_per_rush=4, second_level_yards=55, second_level_yards_per_rush=1.6, open_field_yards=106, open_field_yards_per_rush=3, epa_per_play=0.24, total_epa=14.4, passing_epa=13, epa_per_pass=0.448, rushing_epa=3.9, epa_per_rush=0.111, success_rate=0.438, standard_down_success_rate=0.475, passing_down_success_rate=0.367, explosiveness=0.766, deserve_to_win=0.959)], drives=[LiveGameDrive(id='4017545451', offense_id=183, offense='Syracuse', defense_id=150, defense='Duke', play_count=5, yards=53, start_period=1, start_clock='14:54', start_yards_to_goal=89, end_period=1, end_clock='13:32', end_yards_to_goal=36, duration='1:22', scoring_opportunity=True, result='Interception', points_gained=0, plays=[LiveGamePlay(id='401754545101854501', home_score=0, away_score=0, period=1, clock='14:54', wall_clock=datetime.datetime(2025, 9, 27, 16, 4, 12, tzinfo=datetime.timezone.utc), team_id=150, team='Duke', down=1, distance=10, yards_to_goal=65, yards_gained=11, play_type_id=12, play_type='Kickoff Return (Offense)', epa=None, garbage_time=False, success=True, rush_pass='other', down_type='standard', play_text='Todd Pelino kickoff for 65 yds , Jaden Hart return for 11 yds to the SYR 11'), LiveGamePlay(id='401754545101855102', home_score=0, away_score=0, period=1, clock='14:48', wall_clock=datetime.datetime(2025, 9, 27, 16, 4, 57, tzinfo=datetime.timezone.utc), team_id=183, team='Syracuse', down=1, distance=10, yards_to_goal=89, yards_gained=33, play_type_id=24, play_type='Pass Reception', epa=2.394, garbage_time=False, success=True, rush_pass='pass', down_type='standard', play_text='Rickie Collins pass complete to Johntay Cook for 18 yds to the SYR 29 for a 1ST down Duke Penalty, Personal Foul (Chandler Rivers) to the SYR 44 for a 1ST down'), LiveGamePlay(id='401754545101857601', home_score=0, away_score=0, period=1, clock='14:23', wall_clock=datetime.datetime(2025, 9, 27, 16, 6, 3, tzinfo=datetime.timezone.utc), team_id=183, team='Syracuse', down=1, distance=10, yards_to_goal=56, yards_gained=6, play_type_id=5, play_type='Rush', epa=0.387, garbage_time=False, success=True, rush_pass='rush', down_type='standard', play_text='Will Nixon run for 6 yds to the 50 yard line'), LiveGamePlay(id='401754545101859501', home_score=0, away_score=0, period=1, clock='14:04', wall_clock=datetime.datetime(2025, 9, 27, 16, 7, 39, tzinfo=datetime.timezone.utc), team_id=183, team='Syracuse', down=2, distance=4, yards_to_goal=50, yards_gained=0, play_type_id=3, play_type='Pass Incompletion', epa=-1.237, garbage_time=False, success=False, rush_pass='pass', down_type='standard', play_text='Rickie Collins pass incomplete to Dan Villari'), LiveGamePlay(id='401754545101864901', home_score=0, away_score=0, period=1, clock='13:50', wall_clock=datetime.datetime(2025, 9, 27, 16, 8, 19, tzinfo=datetime.timezone.utc), team_id=183, team='Syracuse', down=3, distance=4, yards_to_goal=50, yards_gained=14, play_type_id=24, play_type='Pass Reception', epa=2.209, garbage_time=False, success=True, rush_pass='pass', down_type='standard', play_text='Rickie Collins pas ...
# 401752717
# The response of PlaysApi->get_live_plays:
#
# LiveGame(id=401752717, status='Final', period=None, clock='', possession='', down=None, distance=None, yards_to_goal=None, teams=[LiveGameTeam(team_id=8, team='Arkansas', home_away='home', line_scores=[3, 10, 0, 0], points=13, drives=10, scoring_opportunities=6, points_per_opportunity=2.2, average_start_yard_line=73.5, plays=77, line_yards=93.9, line_yards_per_rush=3.4, second_level_yards=41, second_level_yards_per_rush=1.5, open_field_yards=83, open_field_yards_per_rush=3, epa_per_play=0.214, total_epa=12.6, passing_epa=2.2, epa_per_pass=0.063, rushing_epa=10.5, epa_per_rush=0.375, success_rate=0.416, standard_down_success_rate=0.529, passing_down_success_rate=0.192, explosiveness=0.993, deserve_to_win=0.004), LiveGameTeam(team_id=87, team='Notre Dame', home_away='away', line_scores=[14, 28, 7, 7], points=56, drives=10, scoring_opportunities=9, points_per_opportunity=6.2, average_start_yard_line=71.2, plays=90, line_yards=143.8, line_yards_per_rush=3.7, second_level_yards=51, second_level_yards_per_rush=1.3, open_field_yards=57, open_field_yards_per_rush=1.5, epa_per_play=0.42, total_epa=26.5, passing_epa=24.4, epa_per_pass=0.74, rushing_epa=2.1, epa_per_rush=0.053, success_rate=0.478, standard_down_success_rate=0.443, passing_down_success_rate=0.552, explosiveness=1.022, deserve_to_win=0.996)], drives=[LiveGameDrive(id='4017527171', offense_id=8, offense='Arkansas', defense_id=87, defense='Notre Dame', play_count=7, yards=54, start_period=1, start_clock='15:00', start_yards_to_goal=75, end_period=1, end_clock='12:55', end_yards_to_goal=21, duration='2:05', scoring_opportunity=True, result='Field Goal', points_gained=3, plays=[LiveGamePlay(id='401752717101849902', home_score=0, away_score=0, period=1, clock='15:00', wall_clock=datetime.datetime(2025, 9, 27, 16, 7, 52, tzinfo=datetime.timezone.utc), team_id=87, team='Notre Dame', down=1, distance=10, yards_to_goal=65, yards_gained=0, play_type_id=53, play_type='Kickoff', epa=None, garbage_time=False, success=False, rush_pass='other', down_type='standard', play_text='Erik Schmidt kickoff for 65 yds for a touchback'), LiveGamePlay(id='401752717101854301', home_score=0, away_score=0, period=1, clock='14:56', wall_clock=datetime.datetime(2025, 9, 27, 16, 8, 47, tzinfo=datetime.timezone.utc), team_id=8, team='Arkansas', down=1, distance=10, yards_to_goal=75, yards_gained=0, play_type_id=3, play_type='Pass Incompletion', epa=-0.703, garbage_time=False, success=False, rush_pass='pass', down_type='standard', play_text="Taylen Green pass incomplete to O'Mega Blake"), LiveGamePlay(id='401752717101855101', home_score=0, away_score=0, period=1, clock='14:48', wall_clock=datetime.datetime(2025, 9, 27, 16, 9, 15, tzinfo=datetime.timezone.utc), team_id=8, team='Arkansas', down=2, distance=10, yards_to_goal=75, yards_gained=14, play_type_id=5, play_type='Rush', epa=1.926, garbage_time=False, success=True, rush_pass='rush', down_type='passing', play_text='Taylen Green run for 14 yds to the ARK 39 for a 1ST down'), LiveGamePlay(id='401752717101857401', home_score=0, away_score=0, period=1, clock='14:25', wall_clock=datetime.datetime(2025, 9, 27, 16, 9, 55, tzinfo=datetime.timezone.utc), team_id=8, team='Arkansas', down=1, distance=10, yards_to_goal=61, yards_gained=33, play_type_id=24, play_type='Pass Reception', epa=2.091, garbage_time=False, success=True, rush_pass='pass', down_type='standard', play_text="Taylen Green pass complete to O'Mega Blake for 33 yds to the ND 28 for a 1ST down"), LiveGamePlay(id='401752717101864501', home_score=0, away_score=0, period=1, clock='13:54', wall_clock=datetime.datetime(2025, 9, 27, 16, 10, 8, tzinfo=datetime.timezone.utc), team_id=8, team='Arkansas', down=1, distance=10, yards_to_goal=28, yards_gained=7, play_type_id=5, play_type='Rush', epa=0.343, garbage_time=False, success=True, rush_pass='rush', down_type='standard', play_text='Braylen Russell run for 7 yds to the ND 21'), LiveGamePlay(id='401752717101867702', home_score=0, away_score=0, period=1, clo ...
# 401752725
# The response of PlaysApi->get_live_plays:
#
# LiveGame(id=401752725, status='Final', period=None, clock='', possession='', down=None, distance=None, yards_to_goal=None, teams=[LiveGameTeam(team_id=238, team='Vanderbilt', home_away='home', line_scores=[7, 24, 17, 7], points=55, drives=13, scoring_opportunities=9, points_per_opportunity=5.3, average_start_yard_line=66.8, plays=82, line_yards=126.10000000000001, line_yards_per_rush=4.3, second_level_yards=43, second_level_yards_per_rush=1.5, open_field_yards=78, open_field_yards_per_rush=2.7, epa_per_play=0.241, total_epa=13.7, passing_epa=2.7, epa_per_pass=0.077, rushing_epa=11, epa_per_rush=0.381, success_rate=0.512, standard_down_success_rate=0.484, passing_down_success_rate=0.6, explosiveness=0.683, deserve_to_win=0.89), LiveGameTeam(team_id=328, team='Utah State', home_away='away', line_scores=[7, 14, 0, 14], points=35, drives=12, scoring_opportunities=6, points_per_opportunity=5.8, average_start_yard_line=76.4, plays=85, line_yards=85.39999999999999, line_yards_per_rush=3.7, second_level_yards=25, second_level_yards_per_rush=1.1, open_field_yards=65, open_field_yards_per_rush=2.8, epa_per_play=0.179, total_epa=10.4, passing_epa=2.3, epa_per_pass=0.059, rushing_epa=8.1, epa_per_rush=0.35, success_rate=0.353, standard_down_success_rate=0.451, passing_down_success_rate=0.206, explosiveness=0.8, deserve_to_win=0.10999999999999999)], drives=[LiveGameDrive(id='4017527251', offense_id=328, offense='Utah State', defense_id=238, defense='Vanderbilt', play_count=3, yards=4, start_period=1, start_clock='15:00', start_yards_to_goal=75, end_period=1, end_clock='13:36', end_yards_to_goal=71, duration='1:24', scoring_opportunity=False, result='Punt', points_gained=0, plays=[LiveGamePlay(id='401752725101849903', home_score=0, away_score=0, period=1, clock='15:00', wall_clock=datetime.datetime(2025, 9, 27, 16, 51, 15, tzinfo=datetime.timezone.utc), team_id=238, team='Vanderbilt', down=1, distance=10, yards_to_goal=65, yards_gained=0, play_type_id=53, play_type='Kickoff', epa=None, garbage_time=False, success=False, rush_pass='other', down_type='standard', play_text='Brock Taylor kickoff for 65 yds for a touchback'), LiveGamePlay(id='401752725101854901', home_score=0, away_score=0, period=1, clock='14:50', wall_clock=datetime.datetime(2025, 9, 27, 16, 51, 15, tzinfo=datetime.timezone.utc), team_id=328, team='Utah State', down=1, distance=10, yards_to_goal=75, yards_gained=2, play_type_id=24, play_type='Pass Reception', epa=-0.452, garbage_time=False, success=False, rush_pass='pass', down_type='standard', play_text='Bryson Barnes pass complete to Javen Jacobs for 2 yds to the USU 27'), LiveGamePlay(id='401752725101857601', home_score=0, away_score=0, period=1, clock='14:23', wall_clock=datetime.datetime(2025, 9, 27, 16, 51, 15, tzinfo=datetime.timezone.utc), team_id=328, team='Utah State', down=2, distance=8, yards_to_goal=73, yards_gained=2, play_type_id=5, play_type='Rush', epa=-0.313, garbage_time=False, success=False, rush_pass='rush', down_type='passing', play_text='Bryson Barnes run for 2 yds to the USU 29'), LiveGamePlay(id='401752725101865401', home_score=0, away_score=0, period=1, clock='13:45', wall_clock=datetime.datetime(2025, 9, 27, 16, 51, 15, tzinfo=datetime.timezone.utc), team_id=328, team='Utah State', down=3, distance=6, yards_to_goal=71, yards_gained=0, play_type_id=3, play_type='Pass Incompletion', epa=-0.315, garbage_time=False, success=False, rush_pass='pass', down_type='passing', play_text='Bryson Barnes pass incomplete'), LiveGamePlay(id='401752725101866301', home_score=0, away_score=0, period=1, clock='13:36', wall_clock=datetime.datetime(2025, 9, 27, 16, 51, 15, tzinfo=datetime.timezone.utc), team_id=328, team='Utah State', down=4, distance=6, yards_to_goal=71, yards_gained=0, play_type_id=52, play_type='Punt', epa=None, garbage_time=False, success=False, rush_pass='other', down_type='passing', play_text='Landon Rehkow punt for 56 yds')]), LiveGameDrive(id='4017527252', offense_id=238, offense='Vanderbilt', defe ...
# 401752719
# The response of PlaysApi->get_live_plays:
#
# LiveGame(id=401752719, status='Final', period=None, clock='', possession='', down=None, distance=None, yards_to_goal=None, teams=[LiveGameTeam(team_id=145, team='Ole Miss', home_away='home', line_scores=[3, 14, 0, 7], points=24, drives=11, scoring_opportunities=6, points_per_opportunity=4, average_start_yard_line=79.9, plays=112, line_yards=167.3, line_yards_per_rush=3.6, second_level_yards=51, second_level_yards_per_rush=1.1, open_field_yards=47, open_field_yards_per_rush=1, epa_per_play=0.219, total_epa=17.3, passing_epa=24.2, epa_per_pass=0.638, rushing_epa=-6.9, epa_per_rush=-0.151, success_rate=0.375, standard_down_success_rate=0.391, passing_down_success_rate=0.349, explosiveness=0.904, deserve_to_win=0.937), LiveGameTeam(team_id=99, team='LSU', home_away='away', line_scores=[7, 0, 6, 6], points=19, drives=11, scoring_opportunities=5, points_per_opportunity=2.4, average_start_yard_line=71.7, plays=79, line_yards=67.9, line_yards_per_rush=3.2, second_level_yards=17, second_level_yards_per_rush=0.8, open_field_yards=0, open_field_yards_per_rush=0, epa_per_play=-0.02, total_epa=-1, passing_epa=1.6, epa_per_pass=0.046, rushing_epa=-2.7, epa_per_rush=-0.127, success_rate=0.38, standard_down_success_rate=0.469, passing_down_success_rate=0.233, explosiveness=0.665, deserve_to_win=0.06299999999999994)], drives=[LiveGameDrive(id='4017527191', offense_id=145, offense='Ole Miss', defense_id=99, defense='LSU', play_count=3, yards=0, start_period=1, start_clock='15:00', start_yards_to_goal=75, end_period=1, end_clock='13:33', end_yards_to_goal=75, duration='1:27', scoring_opportunity=False, result='Punt', points_gained=0, plays=[LiveGamePlay(id='401752719101849902', home_score=0, away_score=0, period=1, clock='15:00', wall_clock=datetime.datetime(2025, 9, 27, 19, 44, 52, tzinfo=datetime.timezone.utc), team_id=99, team='LSU', down=1, distance=10, yards_to_goal=65, yards_gained=0, play_type_id=53, play_type='Kickoff', epa=None, garbage_time=False, success=False, rush_pass='other', down_type='standard', play_text='Aeron Burrell kickoff for 65 yds for a touchback'), LiveGamePlay(id='401752719101854401', home_score=0, away_score=0, period=1, clock='14:55', wall_clock=datetime.datetime(2025, 9, 27, 19, 46, 15, tzinfo=datetime.timezone.utc), team_id=145, team='Ole Miss', down=1, distance=10, yards_to_goal=75, yards_gained=3, play_type_id=5, play_type='Rush', epa=-0.296, garbage_time=False, success=False, rush_pass='rush', down_type='standard', play_text='Kewan Lacy run for 3 yds to the MISS 28'), LiveGamePlay(id='401752719101856301', home_score=0, away_score=0, period=1, clock='14:36', wall_clock=datetime.datetime(2025, 9, 27, 19, 46, 36, tzinfo=datetime.timezone.utc), team_id=145, team='Ole Miss', down=2, distance=7, yards_to_goal=72, yards_gained=2, play_type_id=24, play_type='Pass Reception', epa=-0.363, garbage_time=False, success=False, rush_pass='pass', down_type='passing', play_text="Trinidad Chambliss pass complete to De'Zhaun Stribling for 2 yds to the MISS 30"), LiveGamePlay(id='401752719101859501', home_score=0, away_score=0, period=1, clock='14:04', wall_clock=datetime.datetime(2025, 9, 27, 19, 47, 26, tzinfo=datetime.timezone.utc), team_id=145, team='Ole Miss', down=3, distance=5, yards_to_goal=70, yards_gained=-5, play_type_id=8, play_type='Penalty', epa=None, garbage_time=False, success=False, rush_pass='other', down_type='passing', play_text='Ole Miss Penalty, False Start (Patrick Kutas) to the MISS 25'), LiveGamePlay(id='401752719101866101', home_score=0, away_score=0, period=1, clock='13:38', wall_clock=datetime.datetime(2025, 9, 27, 19, 48, 1, tzinfo=datetime.timezone.utc), team_id=145, team='Ole Miss', down=3, distance=10, yards_to_goal=75, yards_gained=0, play_type_id=3, play_type='Pass Incompletion', epa=-0.159, garbage_time=False, success=False, rush_pass='pass', down_type='passing', play_text="Trinidad Chambliss pass incomplete to Dae'Quan Wright, broken up by PJ Woodland"), LiveGamePlay(id='401752719101866601', home ...
# 401752851
# The response of PlaysApi->get_live_plays:
#
# LiveGame(id=401752851, status='Final', period=None, clock='', possession='', down=None, distance=None, yards_to_goal=None, teams=[LiveGameTeam(team_id=77, team='Northwestern', home_away='home', line_scores=[3, 14, 0, 0], points=17, drives=7, scoring_opportunities=5, points_per_opportunity=2.8, average_start_yard_line=70.6, plays=75, line_yards=150.3, line_yards_per_rush=3.8, second_level_yards=56, second_level_yards_per_rush=1.4, open_field_yards=27, open_field_yards_per_rush=0.7, epa_per_play=0.094, total_epa=5.8, passing_epa=4.1, epa_per_pass=0.187, rushing_epa=5.2, epa_per_rush=0.129, success_rate=0.453, standard_down_success_rate=0.473, passing_down_success_rate=0.4, explosiveness=0.645, deserve_to_win=0.629), LiveGameTeam(team_id=26, team='UCLA', home_away='away', line_scores=[0, 3, 3, 8], points=14, drives=8, scoring_opportunities=5, points_per_opportunity=1.6, average_start_yard_line=82.5, plays=69, line_yards=103.60000000000001, line_yards_per_rush=3.8, second_level_yards=36, second_level_yards_per_rush=1.3, open_field_yards=44, open_field_yards_per_rush=1.6, epa_per_play=0.182, total_epa=10, passing_epa=-1.1, epa_per_pass=-0.034, rushing_epa=11.1, epa_per_rush=0.41, success_rate=0.391, standard_down_success_rate=0.488, passing_down_success_rate=0.25, explosiveness=0.908, deserve_to_win=0.371)], drives=[LiveGameDrive(id='4017528512', offense_id=26, offense='UCLA', defense_id=77, defense='Northwestern', play_count=6, yards=21, start_period=1, start_clock='14:59', start_yards_to_goal=75, end_period=1, end_clock='11:41', end_yards_to_goal=54, duration='3:27', scoring_opportunity=False, result='Punt', points_gained=0, plays=[LiveGamePlay(id='401752851101849902', home_score=0, away_score=0, period=1, clock='15:00', wall_clock=datetime.datetime(2025, 9, 27, 19, 43, 51, tzinfo=datetime.timezone.utc), team_id=77, team='Northwestern', down=1, distance=10, yards_to_goal=65, yards_gained=0, play_type_id=53, play_type='Kickoff', epa=None, garbage_time=False, success=False, rush_pass='other', down_type='standard', play_text='Luke Akers kickoff for 65 yds for a touchback'), LiveGamePlay(id='401752851101854001', home_score=0, away_score=0, period=1, clock='14:59', wall_clock=datetime.datetime(2025, 9, 27, 19, 43, 51, tzinfo=datetime.timezone.utc), team_id=26, team='UCLA', down=1, distance=10, yards_to_goal=75, yards_gained=1, play_type_id=5, play_type='Rush', epa=-0.587, garbage_time=False, success=False, rush_pass='rush', down_type='standard', play_text='Nico Iamaleava run for 1 yd to the UCLA 26'), LiveGamePlay(id='401752851101857301', home_score=0, away_score=0, period=1, clock='14:26', wall_clock=datetime.datetime(2025, 9, 27, 19, 43, 51, tzinfo=datetime.timezone.utc), team_id=26, team='UCLA', down=2, distance=9, yards_to_goal=74, yards_gained=-5, play_type_id=8, play_type='Penalty', epa=None, garbage_time=False, success=False, rush_pass='other', down_type='passing', play_text='UCLA Penalty, false start (Eugene Brooks) to the UCLA 21'), LiveGamePlay(id='401752851101859601', home_score=0, away_score=0, period=1, clock='14:03', wall_clock=datetime.datetime(2025, 9, 27, 19, 43, 51, tzinfo=datetime.timezone.utc), team_id=26, team='UCLA', down=2, distance=14, yards_to_goal=79, yards_gained=7, play_type_id=24, play_type='Pass Reception', epa=0.161, garbage_time=False, success=False, rush_pass='pass', down_type='passing', play_text='Nico Iamaleava pass complete to Titus Mokiao-Atimalala for 7 yds to the UCLA 28'), LiveGamePlay(id='401752851101866501', home_score=0, away_score=0, period=1, clock='13:34', wall_clock=datetime.datetime(2025, 9, 27, 19, 43, 51, tzinfo=datetime.timezone.utc), team_id=26, team='UCLA', down=3, distance=7, yards_to_goal=72, yards_gained=15, play_type_id=24, play_type='Pass Reception', epa=2.468, garbage_time=False, success=True, rush_pass='pass', down_type='passing', play_text='Nico Iamaleava pass complete to Rico Flores Jr. for 15 yds to the UCLA 43 for a 1ST down'), LiveGamePlay(id='401752851101869601', home_s ...

# %% [markdown]
# # Notes
#
# useful -> scoreboard, lines, advanced box scores,
# ### Big games -> Notre Dame, Georgia Tech, Louisville at pitt, usc vs illinois
# --tunnel for npx expo
# the game ids are internal to their api I will need to call games once this can probably be a one time run before running the boxscores api call.
